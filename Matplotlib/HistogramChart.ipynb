# %% [markdown]
# # Histogram Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x=np.random.randint(10,60,(50))
print(x)
# Out:
# [20 53 30 43 17 19 15 10 16 29 22 34 27 23 22 36 47 57 14 54 17 52 51 39
#  36 54 23 24 20 51 23 27 53 53 32 38 48 10 34 36 52 45 32 34 59 17 24 12
#  28 13]

# %%
import matplotlib.pyplot as plt
no=[20, 53, 30, 43, 17, 19, 15, 10, 16, 29, 22, 34, 27, 23, 22, 3,6, 47, 5,7 ,14, 5,4, 17, 52, 51, 39,
 36, 54, 23, 24, 20, 51, 23, 27, 53, 53, 3,2, 38, 48, 10, 34, 36, 52, 45, 32, 34, 59, 17, 24, 12,
 28, 13]
l=[10,20,30,40,50,60]
plt.hist(no,"auto",(0,100),edgecolor="black")

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[20, 53, 30, 43, 17, 19, 15, 10, 16, 29, 22, 34, 27, 23, 22, 3,6, 47, 5,7 ,14, 5,4, 17, 52, 51, 39,
 36, 54, 23, 24, 20, 51, 23, 27, 53, 53, 3,2, 38, 48, 10, 34, 36, 52, 45, 32, 34, 59, 17, 24, 12,
 28, 13]
l=[10,20,30,40,50,60]
plt.hist(no,color="white",bins=l,edgecolor="black",cumulative=-1)

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[20, 53, 30, 43, 17, 19, 15, 10, 16, 29, 22, 34, 27, 23, 22, 3,6, 47, 5,7 ,14, 5,4, 17, 52, 51, 39,
 36, 54, 23, 24, 20, 51, 23, 27, 53, 53, 3,2, 38, 48, 10, 34, 36, 52, 45, 32, 34, 59, 17, 24, 12,
 28, 13]
l=[10,20,30,40,50,60]
plt.hist(no,color="white",bins=l,edgecolor="black",bottom=10) #starts from 10

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[20, 53, 30, 43, 17, 19, 15, 10, 16, 29, 22, 34, 27, 23, 22, 3,6, 47, 5,7 ,14, 5,4, 17, 52, 51, 39,
 36, 54, 23, 24, 20, 51, 23, 27, 53, 53, 3,2, 38, 48, 10, 34, 36, 52, 45, 32, 34, 59, 17, 24, 12,
 28, 13]
l=[10,20,30,40,50,60]
plt.hist(no,color="black",bins=l,edgecolor="white",align ="left") #by default align="mid"

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[20, 53, 30, 43, 17, 19, 15, 10, 16, 29, 22, 34, 27, 23, 22, 3,6, 47, 5,7 ,14, 5,4, 17, 52, 51, 39,
 36, 54, 23, 24, 20, 51, 23, 27, 53, 53, 3,2, 38, 48, 10, 34, 36, 52, 45, 32, 34, 59, 17, 24, 12,
 28, 13]
l=[10,20,30,40,50,60]
plt.hist(no,color="black",bins=l,edgecolor="black",histtype="step")

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[20, 53, 30, 43, 17, 19, 15, 10, 16, 29, 22, 34, 27, 23, 22, 3,6, 47, 5,7 ,14, 5,4, 17, 52, 51, 39,
 36, 54, 23, 24, 20, 51, 23, 27, 53, 53, 3,2, 38, 48, 10, 34, 36, 52, 45, 32, 34, 59, 17, 24, 12,
 28, 13]
l=[10,20,30,40,50,60]
plt.hist(no,color="black",bins=l,edgecolor="red",histtype="stepfilled")

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[20, 53, 30, 43, 17, 19, 15, 10, 16, 29, 22, 34, 27, 23, 22, 3,6, 47, 5,7 ,14, 5,4, 17, 52, 51, 39,
 36, 54, 23, 24, 20, 51, 23, 27, 53, 53, 3,2, 38, 48, 10, 34, 36, 52, 45, 32, 34, 59, 17, 24, 12,
 28, 13]
l=[10,20,30,40,50,60]
plt.hist(no,color="black",bins=l,edgecolor="white",histtype="barstacked")

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[20, 53, 30, 43, 17, 19, 15, 10, 16, 29, 22, 34, 27, 23, 22, 3,6, 47, 5,7 ,14, 5,4, 17, 52, 51, 39,
 36, 54, 23, 24, 20, 51, 23, 27, 53, 53, 3,2, 38, 48, 10, 34, 36, 52, 45, 32, 34, 59, 17, 24, 12,
 28, 13]
l=[10,20,30,40,50,60]
plt.hist(no,color="black",bins=l,edgecolor="white",orientation="horizontal")

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[20, 53, 30, 43, 17, 19, 15, 10, 16, 29, 22, 34, 27, 23, 22, 3,6, 47, 5,7 ,14, 5,4, 17, 52, 51, 39,
 36, 54, 23, 24, 20, 51, 23, 27, 53, 53, 3,2, 38, 48, 10, 34, 36, 52, 45, 32, 34, 59, 17, 24, 12,
 28, 13]
l=[10,20,30,40,50,60]
plt.hist(no,color="black",bins=l,edgecolor="yellow",rwidth=0.8)

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[20, 53, 30, 43, 17, 19, 15, 10, 16, 29, 22, 34, 27, 23, 22, 3,6, 47, 5,7 ,14, 5,4, 17, 52, 51, 39,
 36, 54, 23, 24, 20, 51, 23, 27, 53, 53, 3,2, 38, 48, 10, 34, 36, 52, 45, 32, 34, 59, 17, 24, 12,
 28, 13]
l=[10,20,30,40,50,60]
plt.hist(no,color="black",bins=l,edgecolor="yellow",log="true")#watch left numbering

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[20, 53, 30, 43, 17, 19, 15, 10, 16, 29, 22, 34, 27, 23, 22, 3,6, 47, 5,7 ,14, 5,4, 17, 52, 51, 39,
 36, 54, 23, 24, 20, 51, 23, 27, 53, 53, 3,2, 38, 48, 10, 34, 36, 52, 45, 32, 34, 59, 17, 24, 12,
 28, 13]
l=[10,20,30,40,50,60]
plt.hist(no,color="black",bins=l,edgecolor="yellow",label="python")

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
no=[20, 53, 30, 43, 17, 19, 15, 10, 16, 29, 22, 34, 27, 23, 22, 3,6, 47, 5,7 ,14, 5,4, 17, 52, 51, 39,
 36, 54, 23, 24, 20, 51, 23, 27, 53, 53, 3,2, 38, 48, 10, 34, 36, 52, 45, 32, 34, 59, 17, 24, 12,
 28, 13]
l=[10,20,30,40,50,60]
plt.hist(no,color="black",bins=l,edgecolor="yellow",label="python")

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")

plt.axvline(40,color="m" , label="line")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
no=[20, 53, 30, 43, 17, 19, 15, 10, 16, 29, 22, 34, 27, 23, 22, 3,6, 47, 5,7 ,14, 5,4, 17, 52, 51, 39,
 36, 54, 23, 24, 20, 51, 23, 27, 53, 53, 3,2, 38, 48, 10, 34, 36, 52, 45, 32, 34, 59, 17, 24, 12,
 28, 13]
l=[10,20,30,40,50,60]
plt.hist(no,color="black",bins=l,edgecolor="yellow",label="python")

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")

plt.axvline(40,color="m" , label="line")
plt.legend()
plt.grid()# yes you can choose color for your grid passing color argument
plt.show()
